# %% [markdown]
# <a href="https://colab.research.google.com/github/bhagyashrijainar1-web/intern-eligibility/blob/main/Task3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

data = np.array([12, 15, 20, 20, 25, 30, 35, 40])
np.mean(data)
# Out:
# np.float64(24.625)

# %%
import numpy as np

data = np.array([12, 15, 20, 20, 25, 30, 35, 40])
np.median(data)
# Out:
# np.float64(22.5)

# %%
import numpy as np

data = np.array([12, 15, 20, 20, 25, 30, 35, 40])
np.var(data)
# Out:
# np.float64(83.484375)

# %%
import numpy as np

data = np.array([12, 15, 20, 20, 25, 30, 35, 40])
np.std(data)
# Out:
# np.float64(9.136978439287246)
