# %% [markdown]
# <a href="https://colab.research.google.com/github/bhagyashrijainar1-web/intern-eligibility/blob/main/Task5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

data = np.array([12, 15, 20, 20, 25, 30, 35, 40])
highest = np.max(data)
lowest = np.min(data)
average = np.mean(data)
pass_count = np.sum(data >= 20)

print("Highest Marks:", highest)
print("Lowest Marks:", lowest)
print("Pass Students:", pass_count)
print("Average Marks:", average)

if average < 20:
    print("Class Performance: Poor")
elif average < 30:
    print("Class Performance: Average")
else:
    print("Class Performance: Good")
# Out:
# Highest Marks: 40
# Lowest Marks: 12
# Pass Students: 6
# Average Marks: 24.625
# Class Performance: Average
